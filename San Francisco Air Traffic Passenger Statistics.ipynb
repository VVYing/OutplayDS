# %% [markdown]
# # San Francisco Air Traffic Passenger Statistics
#
# # [Google Colaboratory](https://colab.research.google.com/notebooks/intro.ipynb)
#
# ### Download and install Spark

# %%
# !apt-get update 
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null 
# !wget -q https://downloads.apache.org/spark/spark-3.1.2/spark-3.1.2-bin-hadoop3.2.tgz
# !tar xf spark-3.1.2-bin-hadoop3.2.tgz 
# !pip install -q findspark
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,221 kB]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,418 kB]
# Get:16 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [473 kB]
# Get:17 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,780 kB]
# Ign:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages
# Get:20 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [634 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,657 kB]
# Get:22 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [910 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [506 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,188 kB]
# Get:25 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [40.8 kB]
# Get:26 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [41.5 kB]
# Fetched 13.2 MB in 4s (3,689 kB/s)
# Reading package lists... Done

# %% [markdown]
# ### Setup environment

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.2-bin-hadoop3.2"
import findspark
findspark.init()
from pyspark import SparkContext
sc = SparkContext.getOrCreate()
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate() 
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://42edf6a04936:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Import San Francisco Air Traffic Passenger Statistics Data from DataSF

# %%
# !wget -O SFO.csv https://data.sfgov.org/api/views/rkru-6vcg/rows.csv?accessType=DOWNLOAD
# Out:
# --2021-07-05 20:50:55--  https://data.sfgov.org/api/views/rkru-6vcg/rows.csv?accessType=DOWNLOAD
# Resolving data.sfgov.org (data.sfgov.org)... 52.206.140.199, 52.206.68.26, 52.206.140.205
# Connecting to data.sfgov.org (data.sfgov.org)|52.206.140.199|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘SFO.csv’
#
# SFO.csv                 [  <=>               ]   2.30M  7.33MB/s    in 0.3s
#
# 2021-07-05 20:50:55 (7.33 MB/s) - ‘SFO.csv’ saved [2417417]

# %%
ls
# Out:
# sample_data/  spark-3.1.2-bin-hadoop3.2/
# SFO.csv       spark-3.1.2-bin-hadoop3.2.tgz

# %%
SFO = spark.read.csv('SFO.csv',header=True)
SFO.show(5)
# Out:
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+----------+-------------+---------------+
# |Activity Period|Operating Airline|Operating Airline IATA Code|Published Airline|Published Airline IATA Code|  GEO Summary|GEO Region|Activity Type Code|Price Category Code|  Terminal|Boarding Area|Passenger Count|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+----------+-------------+---------------+
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|        US|          Deplaned|           Low Fare|Terminal 1|            B|          27271|
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|        US|          Enplaned|           Low Fare|Terminal 1|            B|          29131|
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|        US|    Thru / Transit|           Low Fare|Terminal 1|            B|           5415|
# |         200507|       Air Canada|                         AC|       Air Canada|                         AC|International|    Canada|          Deplaned|              Other|Terminal 1|            B|          35156|
# |         200507|       Air Canada|                         AC|       Air Canada|                         AC|International|    Canada|          Enplaned|              Other|Terminal 1|            B|          34090|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+----------+-------------+---------------+
# only showing top 5 rows

# %%
SFO = SFO.withColumnRenamed("Activity Period", "Activity_Period").withColumnRenamed(
    "Operating Airline", "Operating_Airline").withColumnRenamed(
    "Operating Airline IATA Code", "Operating_Airline_IATA_Code").withColumnRenamed(
    "Published Airline", "Published_Airline").withColumnRenamed(
    "Published Airline IATA Code", "Published_Airline_IATA_Code").withColumnRenamed(
    "GEO Summary", "GEO_Summary").withColumnRenamed(
    "GEO Region", "GEO_Region").withColumnRenamed(
    "Activity Type Code", "Activity_Type_Code").withColumnRenamed(
    "Price Category Code", "Price_Category_Code").withColumnRenamed(
    "Boarding Area", "Boarding_Area").withColumnRenamed(
    "Passenger Count", "Passenger_Count"
)

# %%
from pyspark.sql.functions import col

SFO = SFO.withColumn("Activity_Period", col("Activity_Period").cast("int"))
SFO = SFO.withColumn("Passenger_Count", col("Passenger_Count").cast("int"))

# %%
SFO.describe().show()
# Out:
# +-------+------------------+--------------------+---------------------------+--------------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+------------------+
# |summary|   Activity_Period|   Operating_Airline|Operating_Airline_IATA_Code|   Published_Airline|Published_Airline_IATA_Code|  GEO_Summary|GEO_Region|Activity_Type_Code|Price_Category_Code|     Terminal|Boarding_Area|   Passenger_Count|
# +-------+------------------+--------------------+---------------------------+--------------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+------------------+
# |  count|             23178|               23178|                      23104|               23178|                      23104|        23178|     23178|             23178|              23178|        23178|        23178|             23178|
# |   mean|201317.78233669858|                null|                       null|                null|                       null|         null|      null|              null|               null|         null|         null|28930.892441107946|
# | stddev| 454.9114933634974|                null|                       null|                null|                       null|         null|      null|              null|               null|         null|         null| 60886.84752255012|
# |    min|            200507|ABC Aerolineas S....|                         4O|ABC Aerolineas S....|                         4O|     Domestic|      Asia|          Deplaned|           Low Fare|International|            A|                 1|
# |    max|            202103|        Xtra Airways|                         YX|        Xtra Airways|                         YX|International|        US|    Thru / Transit|              Other|   Terminal 3|        Other|            659837|
# +-------+------------------+--------------------+---------------------------+--------------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+------------------+

# %%
SFO.stat.freqItems(('Operating_Airline','Price_Category_Code','Terminal')).show()
# Out:
# +---------------------------+-----------------------------+--------------------+
# |Operating_Airline_freqItems|Price_Category_Code_freqItems|  Terminal_freqItems|
# +---------------------------+-----------------------------+--------------------+
# |       [Horizon Air, Mes...|            [Low Fare, Other]|[International, T...|
# +---------------------------+-----------------------------+--------------------+

# %%
SFO.schema
# Out:
# StructType(List(StructField(Activity_Period,IntegerType,true),StructField(Operating_Airline,StringType,true),StructField(Operating_Airline_IATA_Code,StringType,true),StructField(Published_Airline,StringType,true),StructField(Published_Airline_IATA_Code,StringType,true),StructField(GEO_Summary,StringType,true),StructField(GEO_Region,StringType,true),StructField(Activity_Type_Code,StringType,true),StructField(Price_Category_Code,StringType,true),StructField(Terminal,StringType,true),StructField(Boarding_Area,StringType,true),StructField(Passenger_Count,IntegerType,true)))

# %%
SFO.filter(SFO["GEO_Summary"]=="Domestic").count()
# Out:
# 8262

# %%
SFO.filter(SFO["GEO_Summary"]=="International").count()
# Out:
# 14916

# %%
SFO.groupBy("GEO_Region").count().orderBy("count").show()
# Out:
# +-------------------+-----+
# |         GEO_Region|count|
# +-------------------+-----+
# |      South America|   91|
# |        Middle East|  487|
# |    Central America|  501|
# |Australia / Oceania| 1246|
# |             Mexico| 1768|
# |             Canada| 2139|
# |             Europe| 3721|
# |               Asia| 4963|
# |                 US| 8262|
# +-------------------+-----+

# %%
SFO.groupby('GEO_Region').agg({'Passenger_Count': 'mean'}).orderBy("avg(Passenger_Count)").show()
# Out:
# +-------------------+--------------------+
# |         GEO_Region|avg(Passenger_Count)|
# +-------------------+--------------------+
# |      South America|   2756.285714285714|
# |    Central America|   5399.469061876248|
# |Australia / Oceania|   6259.567415730337|
# |             Mexico|    7588.08371040724|
# |        Middle East|   7986.381930184805|
# |             Canada|   9751.680224403926|
# |             Europe|  11369.328943832303|
# |               Asia|  13266.305460407011|
# |                 US|    62151.4109174534|
# +-------------------+--------------------+

# %%
from pyspark.sql import SparkSession
spark = SparkSession \
    .builder \
    .appName("Spark SQL Query Dataframes") \
    .getOrCreate()

# %%
SFO.createOrReplaceTempView("AirTraffic")

# %%
SFO_sql = spark.sql("SELECT * FROM AirTraffic LIMIT 5")
SFO_sql.show()
# Out:
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+----------+-------------+---------------+
# |Activity_Period|Operating_Airline|Operating_Airline_IATA_Code|Published_Airline|Published_Airline_IATA_Code|  GEO_Summary|GEO_Region|Activity_Type_Code|Price_Category_Code|  Terminal|Boarding_Area|Passenger_Count|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+----------+-------------+---------------+
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|        US|          Deplaned|           Low Fare|Terminal 1|            B|          27271|
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|        US|          Enplaned|           Low Fare|Terminal 1|            B|          29131|
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|        US|    Thru / Transit|           Low Fare|Terminal 1|            B|           5415|
# |         200507|       Air Canada|                         AC|       Air Canada|                         AC|International|    Canada|          Deplaned|              Other|Terminal 1|            B|          35156|
# |         200507|       Air Canada|                         AC|       Air Canada|                         AC|International|    Canada|          Enplaned|              Other|Terminal 1|            B|          34090|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+----------+-------------+---------------+

# %%
SFO_sql = spark.sql("SELECT GEO_Region, Terminal As T, Passenger_Count AS PC FROM AirTraffic LIMIT 10")
SFO_sql.show()
# Out:
# +-------------------+-------------+-----+
# |         GEO_Region|            T|   PC|
# +-------------------+-------------+-----+
# |                 US|   Terminal 1|27271|
# |                 US|   Terminal 1|29131|
# |                 US|   Terminal 1| 5415|
# |             Canada|   Terminal 1|35156|
# |             Canada|   Terminal 1|34090|
# |               Asia|International| 6263|
# |               Asia|International| 5500|
# |             Europe|International|12050|
# |             Europe|International|11638|
# |Australia / Oceania|International| 4998|
# +-------------------+-------------+-----+

# %%
df_sql = spark.sql("SELECT * FROM AirTraffic WHERE Activity_Period = 202003")
df_sql.show(5)
df_sql.count()
# Out:
# +---------------+--------------------+---------------------------+--------------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+---------------+
# |Activity_Period|   Operating_Airline|Operating_Airline_IATA_Code|   Published_Airline|Published_Airline_IATA_Code|  GEO_Summary|GEO_Region|Activity_Type_Code|Price_Category_Code|     Terminal|Boarding_Area|Passenger_Count|
# +---------------+--------------------+---------------------------+--------------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+---------------+
# |         202003|ABC Aerolineas S....|                         4O|ABC Aerolineas S....|                         4O|International|    Mexico|          Deplaned|              Other|International|            A|           2158|
# |         202003|ABC Aerolineas S....|                         4O|ABC Aerolineas S....|                         4O|International|    Mexico|          Enplaned|              Other|International|            A|           2152|
# |         202003|          Aer Lingus|                         EI|          Aer Lingus|                         EI|International|    Europe|          Deplaned|              Other|International|            G|           3031|
# |         202003|          Aer Lingus|                         EI|          Aer Lingus|                         EI|International|    Europe|          Enplaned|              Other|International|            G|           3301|
# |         202003|          Aeromexico|                         AM|          Aeromexico|                         AM|International|    Mexico|          Deplaned|              Other|International|            A|           5734|
# +---------------+--------------------+---------------------------+--------------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+---------------+
# only showing top 5 rows
# 140

# %%
df_sql = spark.sql("SELECT * FROM AirTraffic WHERE Passenger_Count > 5000 AND Activity_Period < 202003 ")
df_sql.count()
# Out:
# 16814

# %%
df_sql = spark.sql("SELECT * \
                    FROM AirTraffic \
                    WHERE Passenger_Count > 5000 AND Activity_Period > 202002 \
                    ORDER BY Activity_Period ASC")
df_sql.show(5)
df_sql.count()
# Out:
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+---------------+
# |Activity_Period|Operating_Airline|Operating_Airline_IATA_Code|Published_Airline|Published_Airline_IATA_Code|  GEO_Summary|GEO_Region|Activity_Type_Code|Price_Category_Code|     Terminal|Boarding_Area|Passenger_Count|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+---------------+
# |         202003|       Aeromexico|                         AM|       Aeromexico|                         AM|International|    Mexico|          Deplaned|              Other|International|            A|           5734|
# |         202003|       Aeromexico|                         AM|       Aeromexico|                         AM|International|    Mexico|          Enplaned|              Other|International|            A|           5319|
# |         202003|       Air Canada|                         AC|       Air Canada|                         AC|International|    Canada|          Deplaned|              Other|International|            G|          13330|
# |         202003|       Air Canada|                         AC|       Air Canada|                         AC|International|    Canada|          Enplaned|              Other|International|            G|          20478|
# |         202003|Air India Limited|                         AI|Air India Limited|                         AI|International|      Asia|          Deplaned|              Other|International|            G|           6032|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+----------+------------------+-------------------+-------------+-------------+---------------+
# only showing top 5 rows
# 378

# %%
df_count = spark.sql("SELECT count(*) FROM AirTraffic")
df_count.show()
# Out:
# +--------+
# |count(1)|
# +--------+
# |   23178|
# +--------+

# %%
df_sql = spark.sql("SELECT GEO_Region, min(Passenger_Count), round(avg(Passenger_Count),0), max(Passenger_Count) \
                    FROM AirTraffic \
                    WHERE Activity_Period > 202002 \
                    GROUP BY GEO_Region \
                    ORDER BY count(*) DESC")
df_sql.show()
# Out:
# +-------------------+--------------------+----------------------------------------------+--------------------+
# |         GEO_Region|min(Passenger_Count)|round(avg(CAST(Passenger_Count AS BIGINT)), 0)|max(Passenger_Count)|
# +-------------------+--------------------+----------------------------------------------+--------------------+
# |                 US|                   3|                                       20675.0|              177513|
# |               Asia|                   1|                                        2235.0|               20815|
# |             Europe|                  56|                                        1691.0|               17391|
# |             Mexico|                  18|                                        3453.0|               14801|
# |             Canada|                  28|                                        1716.0|               20478|
# |Australia / Oceania|                  94|                                        2525.0|               19811|
# |    Central America|                   8|                                        1360.0|                4482|
# |        Middle East|                 329|                                        1774.0|                8055|
# +-------------------+--------------------+----------------------------------------------+--------------------+

# %%
df_sql = spark.sql("SELECT GEO_Region, min(Passenger_Count), round(avg(Passenger_Count),0), max(Passenger_Count) \
                    FROM AirTraffic \
                    WHERE Activity_Period < 202001 \
                    GROUP BY GEO_Region \
                    ORDER BY count(*) DESC")
df_sql.show()
# Out:
# +-------------------+--------------------+----------------------------------------------+--------------------+
# |         GEO_Region|min(Passenger_Count)|round(avg(CAST(Passenger_Count AS BIGINT)), 0)|max(Passenger_Count)|
# +-------------------+--------------------+----------------------------------------------+--------------------+
# |                 US|                   1|                                       64492.0|              659837|
# |               Asia|                   2|                                       13882.0|              102939|
# |             Europe|                   1|                                       11968.0|               66961|
# |             Canada|                   1|                                       10064.0|               61749|
# |             Mexico|                   1|                                        7807.0|               35205|
# |Australia / Oceania|                  10|                                        6382.0|               24404|
# |    Central America|                  62|                                        5698.0|               11632|
# |        Middle East|                  82|                                        8461.0|               14906|
# |      South America|                  81|                                        2756.0|                3685|
# +-------------------+--------------------+----------------------------------------------+--------------------+

# %%
sql_window = "SELECT Activity_Period, Activity_Type_Code,  \
              avg(Passenger_Count) OVER (PARTITION BY GEO_Region)  \
FROM  \
      AirTraffic"

# %%
spark.sql(sql_window).show()
# Out:
# +---------------+------------------+----------------------------------------------------------------------------------------------------------------------------+
# |Activity_Period|Activity_Type_Code|avg(CAST(Passenger_Count AS BIGINT)) OVER (PARTITION BY GEO_Region ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING)|
# +---------------+------------------+----------------------------------------------------------------------------------------------------------------------------+
# |         200507|          Deplaned|                                                                                                          11369.328943832303|
# |         200507|          Enplaned|                                                                                                          11369.328943832303|
# |         200507|          Deplaned|                                                                                                          11369.328943832303|
# |         200507|          Enplaned|                                                                                                          11369.328943832303|
# |         200507|          Deplaned|                                                                                                          11369.328943832303|
# |         200507|          Enplaned|                                                                                                          11369.328943832303|
# |         200507|          Deplaned|                                                                                                          11369.328943832303|
# |         200507|          Enplaned|                                                                                                          11369.328943832303|
# |         200507|          Deplaned|                                                                                                          11369.328943832303|
# |         200507|          Enplaned|                                                                                                          11369.328943832303|
# |         200507|          Deplaned|                                                                                                          11369.328943832303|
# |         200507|          Enplaned|                                                                                                          11369.328943832303|
# |         200507|          Deplaned|                                                                                                          11369.328943832303|
# |         200507|          Enplaned|                                                                                                          11369.328943832303|
# |         200507|    Thru / Transit|                                                                                                          11369.328943832303|
# |         200507|          Deplaned|                                                                                                          11369.328943832303|
# |         200507|          Enplaned|                                                                                                          11369.328943832303|
# |         200508|          Deplaned|                                                                                                          11369.328943832303|
# |         200508|          Enplaned|                                                                                                          11369.328943832303|
# |         200508|          Deplaned|                                                                                                          11369.328943832303|
# +---------------+------------------+----------------------------------------------------------------------------------------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# Machine Learning - Clustering

# %%
from pyspark.sql import SparkSession
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.clustering import KMeans

# %%
vectorAssembler = VectorAssembler(inputCols=["Activity_Period", "Passenger_Count"], outputCol="features")

# %%
vcluster_df = vectorAssembler.transform(SFO)

# %%
vcluster_df.show()
# Out:
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+-------------------+------------------+-------------------+-------------+-------------+---------------+------------------+
# |Activity_Period|Operating_Airline|Operating_Airline_IATA_Code|Published_Airline|Published_Airline_IATA_Code|  GEO_Summary|         GEO_Region|Activity_Type_Code|Price_Category_Code|     Terminal|Boarding_Area|Passenger_Count|          features|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+-------------------+------------------+-------------------+-------------+-------------+---------------+------------------+
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|                 US|          Deplaned|           Low Fare|   Terminal 1|            B|          27271|[200507.0,27271.0]|
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|                 US|          Enplaned|           Low Fare|   Terminal 1|            B|          29131|[200507.0,29131.0]|
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|                 US|    Thru / Transit|           Low Fare|   Terminal 1|            B|           5415| [200507.0,5415.0]|
# |         200507|       Air Canada|                         AC|       Air Canada|                         AC|International|             Canada|          Deplaned|              Other|   Terminal 1|            B|          35156|[200507.0,35156.0]|
# |         200507|       Air Canada|                         AC|       Air Canada|                         AC|International|             Canada|          Enplaned|              Other|   Terminal 1|            B|          34090|[200507.0,34090.0]|
# |         200507|        Air China|                         CA|        Air China|                         CA|International|               Asia|          Deplaned|              Other|International|            G|           6263| [200507.0,6263.0]|
# |         200507|        Air China|                         CA|        Air China|                         CA|International|               Asia|          Enplaned|              Other|International|            G|           5500| [200507.0,5500.0]|
# |         200507|       Air France|                         AF|       Air France|                         AF|International|             Europe|          Deplaned|              Other|International|            A|          12050|[200507.0,12050.0]|
# |         200507|       Air France|                         AF|       Air France|                         AF|International|             Europe|          Enplaned|              Other|International|            A|          11638|[200507.0,11638.0]|
# |         200507|  Air New Zealand|                         NZ|  Air New Zealand|                         NZ|International|Australia / Oceania|          Deplaned|              Other|International|            G|           4998| [200507.0,4998.0]|
# |         200507|  Air New Zealand|                         NZ|  Air New Zealand|                         NZ|International|Australia / Oceania|          Enplaned|              Other|International|            G|           4962| [200507.0,4962.0]|
# |         200507|  AirTran Airways|                         FL|  AirTran Airways|                         FL|     Domestic|                 US|          Deplaned|           Low Fare|International|            A|           8055| [200507.0,8055.0]|
# |         200507|  AirTran Airways|                         FL|  AirTran Airways|                         FL|     Domestic|                 US|          Enplaned|           Low Fare|International|            A|           7984| [200507.0,7984.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|     Domestic|                 US|          Deplaned|              Other|International|            A|          36641|[200507.0,36641.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|     Domestic|                 US|          Enplaned|              Other|International|            A|          39379|[200507.0,39379.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|     Domestic|                 US|    Thru / Transit|              Other|International|            A|           3678| [200507.0,3678.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|International|             Canada|          Deplaned|              Other|International|            A|           7977| [200507.0,7977.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|International|             Canada|          Enplaned|              Other|International|            A|           8837| [200507.0,8837.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|International|             Mexico|          Deplaned|              Other|International|            A|           6969| [200507.0,6969.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|International|             Mexico|          Enplaned|              Other|International|            A|          10046|[200507.0,10046.0]|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+-------------------+------------------+-------------------+-------------+-------------+---------------+------------------+
# only showing top 20 rows

# %%
kmeans = KMeans().setK(3)
kmeans = kmeans.setSeed(1)

# %%
kmodel = kmeans.fit(vcluster_df)

# %%
kmodel.clusterCenters()
# Out:
# [array([201317.51953409,  11808.76709537]),
#  array([201386.23643411, 349898.41472868]),
#  array([201303.24307244, 119928.5352455 ])]

# %% [markdown]
# Machine Learning - Linear Regression

# %%
from pyspark.sql import SparkSession
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import VectorAssembler

# %%
vectorAssembler = VectorAssembler(inputCols=["Activity_Period"], outputCol="features")
SFO = vectorAssembler.transform(SFO)
SFO.show()
# Out:
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+-------------------+------------------+-------------------+-------------+-------------+---------------+----------+
# |Activity_Period|Operating_Airline|Operating_Airline_IATA_Code|Published_Airline|Published_Airline_IATA_Code|  GEO_Summary|         GEO_Region|Activity_Type_Code|Price_Category_Code|     Terminal|Boarding_Area|Passenger_Count|  features|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+-------------------+------------------+-------------------+-------------+-------------+---------------+----------+
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|                 US|          Deplaned|           Low Fare|   Terminal 1|            B|          27271|[200507.0]|
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|                 US|          Enplaned|           Low Fare|   Terminal 1|            B|          29131|[200507.0]|
# |         200507|     ATA Airlines|                         TZ|     ATA Airlines|                         TZ|     Domestic|                 US|    Thru / Transit|           Low Fare|   Terminal 1|            B|           5415|[200507.0]|
# |         200507|       Air Canada|                         AC|       Air Canada|                         AC|International|             Canada|          Deplaned|              Other|   Terminal 1|            B|          35156|[200507.0]|
# |         200507|       Air Canada|                         AC|       Air Canada|                         AC|International|             Canada|          Enplaned|              Other|   Terminal 1|            B|          34090|[200507.0]|
# |         200507|        Air China|                         CA|        Air China|                         CA|International|               Asia|          Deplaned|              Other|International|            G|           6263|[200507.0]|
# |         200507|        Air China|                         CA|        Air China|                         CA|International|               Asia|          Enplaned|              Other|International|            G|           5500|[200507.0]|
# |         200507|       Air France|                         AF|       Air France|                         AF|International|             Europe|          Deplaned|              Other|International|            A|          12050|[200507.0]|
# |         200507|       Air France|                         AF|       Air France|                         AF|International|             Europe|          Enplaned|              Other|International|            A|          11638|[200507.0]|
# |         200507|  Air New Zealand|                         NZ|  Air New Zealand|                         NZ|International|Australia / Oceania|          Deplaned|              Other|International|            G|           4998|[200507.0]|
# |         200507|  Air New Zealand|                         NZ|  Air New Zealand|                         NZ|International|Australia / Oceania|          Enplaned|              Other|International|            G|           4962|[200507.0]|
# |         200507|  AirTran Airways|                         FL|  AirTran Airways|                         FL|     Domestic|                 US|          Deplaned|           Low Fare|International|            A|           8055|[200507.0]|
# |         200507|  AirTran Airways|                         FL|  AirTran Airways|                         FL|     Domestic|                 US|          Enplaned|           Low Fare|International|            A|           7984|[200507.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|     Domestic|                 US|          Deplaned|              Other|International|            A|          36641|[200507.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|     Domestic|                 US|          Enplaned|              Other|International|            A|          39379|[200507.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|     Domestic|                 US|    Thru / Transit|              Other|International|            A|           3678|[200507.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|International|             Canada|          Deplaned|              Other|International|            A|           7977|[200507.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|International|             Canada|          Enplaned|              Other|International|            A|           8837|[200507.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|International|             Mexico|          Deplaned|              Other|International|            A|           6969|[200507.0]|
# |         200507|  Alaska Airlines|                         AS|  Alaska Airlines|                         AS|International|             Mexico|          Enplaned|              Other|International|            A|          10046|[200507.0]|
# +---------------+-----------------+---------------------------+-----------------+---------------------------+-------------+-------------------+------------------+-------------------+-------------+-------------+---------------+----------+
# only showing top 20 rows

# %%
lr = LinearRegression(featuresCol="features",labelCol="Passenger_Count")

# %%
lrModel = lr.fit(SFO)

# %%
lrModel.coefficients
# Out:
# DenseVector([1.2683])

# %%
lrModel.intercept
# Out:
# -226403.4714729307

# %%
lrModel.summary.rootMeanSquaredError
# Out:
# 60882.80032036311
